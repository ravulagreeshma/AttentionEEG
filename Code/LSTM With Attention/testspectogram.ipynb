# %%
from dataset import DatasetSpectogram

path = "../../../datasets/data_preprocessed_python"

dataset = DatasetSpectogram(path, "Arousal")
# Out:
# (1280, 40, 8064)
# done1
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# (33, 253)
# done2
# done3
# ...
